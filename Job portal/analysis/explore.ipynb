# %%
import sys
sys.path.append(r"C:\Users\Windows\PycharmProjects\Personal_FC\Job portal")

import pandas as pd
import psycopg2
from config import DB_CONFIG

conn = psycopg2.connect(**DB_CONFIG)

df = pd.read_sql("""
    SELECT
        j.title,
        j.department,
        j.location,
        j.first_published,
        j.updated_at,
        j.pay_min,
        j.pay_max,
        j.currency,
        j.description,
        c.name as company
    FROM jobs j
    JOIN companies c ON j.company_id = c.id
""", conn)

conn.close()
df
# Out:
# C:\Users\Windows\AppData\Local\Temp\ipykernel_35396\2615214953.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("""
# C:\Users\Windows\AppData\Local\Temp\ipykernel_35396\2615214953.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("""
#                                                   title    department  \
# 0           Account Executive, Academic Medical Centers         Sales
# 1      Account Executive, Beneficial Deployments - EMEA         Sales
# 2      Account Executive, Beneficial Deployments - EMEA         Sales
# 3     Account Executive, Beneficial Deployments (Fre...         Sales
# ...

# %%
mdf = df[["title","company","department","location","description"]]

# %%
mdf.loc[mdf.location.str.contains('Dublin','Ireland')]
mdf.loc[mdf.location.str.contains("Ireland")]
# Out:
#                                                   title     company  \
# 554   Senior Technical Revenue Analyst (Dublin, Irel...       Figma
# 641             Backend Engineer/API, Payments and Risk      Stripe
# 644                            Business Partner Analyst      Stripe
# 686                                  Engagement Manager      Stripe
# 706                       Enterprise Support Specialist      Stripe
# 722        Financial Data Analyst, Technical Operations      Stripe
# 773                               Integration Engineer       Stripe
# 967                Software Engineer, Payments and Risk      Stripe
# 1015                    Technical Account Manager, Risk      Stripe
# 1027    Technical Partner Manager, EMEA Payment Methods      Stripe
# 1119               Senior Accountant (Dublin, Ireland)        Figma
# 1157                            Sales Manager, Startups      Stripe
# 1163                Product Manager, EMEA Payments Lead      Stripe
# ...
